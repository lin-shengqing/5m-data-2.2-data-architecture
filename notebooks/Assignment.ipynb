# %% [markdown]
# ### Question 1
#
# Question: How would you create a new hash in Redis to store information about a person, with john_doe as the key and include the name (John Doe), age (35), and email address (john@email.com)?

# %%
import redis

r = redis.Redis(
  host='redis-13214.c9.us-east-1-2.ec2.cloud.redislabs.com',
  port=13214,
  password='<pwd>')

# %% [markdown]
# Answer:

# %%
r.hset(
    'john_doe',
    mapping={
        "age": 35,
        "email": "john@email.com",
    },
)
# Out:
# 2

# %%
r.hgetall("john_doe")
# Out:
# {b'age': b'35', b'email': b'john@email.com'}

# %% [markdown]
# ### Question 2
#
# Question: Write Python code to list the first 10 objects (blob name) in the "gcp-public-data-landsat" bucket, along with their sizes.

# %%
from google.cloud import storage

client = storage.Client()
bucket = client.get_bucket("gcp-public-data-landsat")
# Out:
# /home/localuser/miniconda3/envs/bde/lib/python3.10/site-packages/google/api_core/_python_version_support.py:266: FutureWarning: You are using a Python version (3.10.13) which Google will stop supporting in new releases of google.api_core once it reaches its end of life (2026-10-04). Please upgrade to the latest Python version, or at least Python 3.11, to continue receiving updates for google.api_core past that date.
#   warnings.warn(message, FutureWarning)

# %% [markdown]
# Answer:

# %%
blobs = bucket.list_blobs()

print("Blobs in {}:".format(bucket.name))
for ix, item in enumerate(blobs):
    print("\t" + item.name + " \tSize: " + str(item.size))
    if ix == 10:
        break
# Out:
# Blobs in gcp-public-data-landsat:
# 	LC08/01/001/002/LC08_L1GT_001002_20160817_20170322_01_T2/LC08_L1GT_001002_20160817_20170322_01_T2_ANG.txt 	Size: 117255
# 	LC08/01/001/002/LC08_L1GT_001002_20160817_20170322_01_T2/LC08_L1GT_001002_20160817_20170322_01_T2_B1.TIF 	Size: 75085385
# 	LC08/01/001/002/LC08_L1GT_001002_20160817_20170322_01_T2/LC08_L1GT_001002_20160817_20170322_01_T2_B10.TIF 	Size: 40612836
# 	LC08/01/001/002/LC08_L1GT_001002_20160817_20170322_01_T2/LC08_L1GT_001002_20160817_20170322_01_T2_B11.TIF 	Size: 39267654
# 	LC08/01/001/002/LC08_L1GT_001002_20160817_20170322_01_T2/LC08_L1GT_001002_20160817_20170322_01_T2_B2.TIF 	Size: 76259448
# 	LC08/01/001/002/LC08_L1GT_001002_20160817_20170322_01_T2/LC08_L1GT_001002_20160817_20170322_01_T2_B3.TIF 	Size: 76813565
# 	LC08/01/001/002/LC08_L1GT_001002_20160817_20170322_01_T2/LC08_L1GT_001002_20160817_20170322_01_T2_B4.TIF 	Size: 78510140
# 	LC08/01/001/002/LC08_L1GT_001002_20160817_20170322_01_T2/LC08_L1GT_001002_20160817_20170322_01_T2_B5.TIF 	Size: 80344717
# 	LC08/01/001/002/LC08_L1GT_001002_20160817_20170322_01_T2/LC08_L1GT_001002_20160817_20170322_01_T2_B6.TIF 	Size: 76416634
# 	LC08/01/001/002/LC08_L1GT_001002_20160817_20170322_01_T2/LC08_L1GT_001002_20160817_20170322_01_T2_B7.TIF 	Size: 73888286
# 	LC08/01/001/002/LC08_L1GT_001002_20160817_20170322_01_T2/LC08_L1GT_001002_20160817_20170322_01_T2_B8.TIF 	Size: 292255055
